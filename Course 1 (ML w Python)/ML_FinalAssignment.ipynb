# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align="center"><font size="5">Final Project: Classification with Python</font></h1>

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#     <li><a href="https://#Section_1">Instructions</a></li>
#     <li><a href="https://#Section_2">About the Data</a></li>
#     <li><a href="https://#Section_3">Importing Data </a></li>
#     <li><a href="https://#Section_4">Data Preprocessing</a> </li>
#     <li><a href="https://#Section_5">One Hot Encoding </a></li>
#     <li><a href="https://#Section_6">Train and Test Data Split </a></li>
#     <li><a href="https://#Section_7">Train Logistic Regression, KNN, Decision Tree, SVM, and Linear Regression models and return their appropriate accuracy scores</a></li>
# </a></li>
# </div>
# <p>Estimated Time Needed: <strong>180 min</strong></p>
# </div>
#
# <hr>

# %% [markdown]
# # Instructions

# %% [markdown]
# In this notebook, you will  practice all the classification algorithms that we have learned in this course.
#
#
# Below, is where we are going to use the classification algorithms to create a model based on our training data and evaluate our testing data using evaluation metrics learned in the course.
#
# We will use some of the algorithms taught in the course, specifically:
#
# 1. Linear Regression
# 2. KNN
# 3. Decision Trees
# 4. Logistic Regression
# 5. SVM
#
# We will evaluate our models using:
#
# 1.  Accuracy Score
# 2.  Jaccard Index
# 3.  F1-Score
# 4.  LogLoss
# 5.  Mean Absolute Error
# 6.  Mean Squared Error
# 7.  R2-Score
#
# Finally, you will use your models to generate the report at the end.

# %% [markdown]
# # About The Dataset

# %% [markdown]
# The original source of the data is Australian Government's Bureau of Meteorology and the latest data can be gathered from [http://www.bom.gov.au/climate/dwo/](http://www.bom.gov.au/climate/dwo/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01).
#
# The dataset to be used has extra columns like 'RainToday' and our target is 'RainTomorrow', which was gathered from the Rattle at [https://bitbucket.org/kayontoga/rattle/src/master/data/weatherAUS.RData](https://bitbucket.org/kayontoga/rattle/src/master/data/weatherAUS.RData?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01)

# %% [markdown]
# This dataset contains observations of weather metrics for each day from 2008 to 2017. The **weatherAUS.csv** dataset includes the following fields:
#
# | Field         | Description                                           | Unit            | Type   |
# | ------------- | ----------------------------------------------------- | --------------- | ------ |
# | Date          | Date of the Observation in YYYY-MM-DD                 | Date            | object |
# | Location      | Location of the Observation                           | Location        | object |
# | MinTemp       | Minimum temperature                                   | Celsius         | float  |
# | MaxTemp       | Maximum temperature                                   | Celsius         | float  |
# | Rainfall      | Amount of rainfall                                    | Millimeters     | float  |
# | Evaporation   | Amount of evaporation                                 | Millimeters     | float  |
# | Sunshine      | Amount of bright sunshine                             | hours           | float  |
# | WindGustDir   | Direction of the strongest gust                       | Compass Points  | object |
# | WindGustSpeed | Speed of the strongest gust                           | Kilometers/Hour | object |
# | WindDir9am    | Wind direction averaged of 10 minutes prior to 9am    | Compass Points  | object |
# | WindDir3pm    | Wind direction averaged of 10 minutes prior to 3pm    | Compass Points  | object |
# | WindSpeed9am  | Wind speed averaged of 10 minutes prior to 9am        | Kilometers/Hour | float  |
# | WindSpeed3pm  | Wind speed averaged of 10 minutes prior to 3pm        | Kilometers/Hour | float  |
# | Humidity9am   | Humidity at 9am                                       | Percent         | float  |
# | Humidity3pm   | Humidity at 3pm                                       | Percent         | float  |
# | Pressure9am   | Atmospheric pressure reduced to mean sea level at 9am | Hectopascal     | float  |
# | Pressure3pm   | Atmospheric pressure reduced to mean sea level at 3pm | Hectopascal     | float  |
# | Cloud9am      | Fraction of the sky obscured by cloud at 9am          | Eights          | float  |
# | Cloud3pm      | Fraction of the sky obscured by cloud at 3pm          | Eights          | float  |
# | Temp9am       | Temperature at 9am                                    | Celsius         | float  |
# | Temp3pm       | Temperature at 3pm                                    | Celsius         | float  |
# | RainToday     | If there was rain today                               | Yes/No          | object |
# | RainTomorrow  | If there is rain tomorrow                             | Yes/No          | float  |
#
# Column definitions were gathered from [http://www.bom.gov.au/climate/dwo/IDCJDW0000.shtml](http://www.bom.gov.au/climate/dwo/IDCJDW0000.shtml?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01)

# %% [markdown]
# ## **Import the required libraries**

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix, accuracy_score
import sklearn.metrics as metrics

# %% [markdown]
# ### Importing the Dataset

# %%
df = pd.read_csv("Weather_Data.csv")

# %% [markdown]
# > Note: This version of the lab is designed for JupyterLite, which necessitates downloading the dataset to the interface. However, when working with the downloaded version of this notebook on your local machines (Jupyter Anaconda), you can simply **skip the steps above of "Importing the Dataset"** and use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### One Hot Encoding

# %% [markdown]
# First, we need to perform one hot encoding to convert categorical variables to binary variables.

# %%
df_sydney_processed = pd.get_dummies(data=df, columns=['RainToday', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %% [markdown]
# Next, we replace the values of the 'RainTomorrow' column changing them from a categorical column to a binary column. We do not use the `get_dummies` method because we would end up with two columns for 'RainTomorrow' and we do not want, since 'RainTomorrow' is our target.

# %%
### Training Data and Test Data
# I added the following line to eliminate a "future warning" about downcasting functionality that was being deprecated in a future version.
pd.set_option('future.no_silent_downcasting', True)
df_sydney_processed.replace(['No', 'Yes'], [0,1], inplace=True)

# %% [markdown]
# ### Training Data and Test Data

# %% [markdown]
# Now, we set our 'features' or x values and our Y or target variable.

# %%
df_sydney_processed.drop('Date',axis=1,inplace=True)

# %%
df_sydney_processed = df_sydney_processed.astype(float)

# %%
features = df_sydney_processed.drop(columns='RainTomorrow', axis=1)
Y = df_sydney_processed['RainTomorrow']

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### Q1) Use the `train_test_split` function to split the `features` and `Y` dataframes with a `test_size` of `0.2` and the `random_state` set to `10`.

# %%
#Enter Your Code and Execute
'''A standard scaler is used to standardize features by removing the mean and scaling to unit variance (i.e., the features are centered around zero with a standard deviation of one). This preprocessing step is essential in machine learning because:
    o Feature Scaling: It ensures that all features contribute equally to the model's performance, especially when they are measured on different scales (e.g., age in years, income in thousands).
    o Convergence: In gradient-based optimization algorithms (like those used in linear and logistic regression), standardizing features can improve convergence speed by making the optimization landscape smoother.
    o Avoiding Dominance: Prevents features with larger scales from dominating the learning process.'''
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size = 0.2, random_state = 10)

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data
x_train_scaled = scaler.fit_transform(x_train)

# Transform the test data using the same scaler
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# #### Q2) Create and train a Linear Regression model called LinearReg using the training data (`x_train`, `y_train`).

# %%
#Enter Your Code and Execute
from sklearn.linear_model import LinearRegression

# Step 1: Create an instance of the Linear Regression model
LinearReg = LinearRegression()

# Step 2: Train the model using the training data
LinearReg.fit(x_train_scaled, y_train)
print ('Coefficients: ', LinearReg.coef_)
print ('Intercept: ',LinearReg.intercept_)
# The model is now trained and you can use it to make predictions
# Out:
# Coefficients:  [-1.08160174e-01  5.80729389e-02  7.30309514e-03  1.78610337e-02
#  -1.33894701e-01  4.49014674e-02  1.28732541e-02  5.89917812e-03
#   1.44342721e-02  1.37707619e-01  5.41419862e-02 -6.47456774e-02
#  -2.25179034e-02  2.44418876e-02  7.12520639e-02 -1.48554930e-02
#  -2.33815475e-02  2.33815475e-02  1.10279011e-02 -1.73608313e-02
#   1.50436580e-02 -5.80288541e-03 -1.11416195e-02 -1.56894033e-02
#  -8.84917159e-03  1.08005232e-02  3.63854960e-05  1.68511952e-02
#   5.79113691e-03  1.04501536e-02  5.63240076e-03 -6.33983330e-03
#   1.94802546e-03  4.93461202e-03  9.54615059e-03  8.59240510e-03
#  -8.18501495e-04 -2.84804980e-03 -1.81403012e-03 -5.00339402e-04
#  -1.28707086e-02  7.35188891e-03 -9.70960276e-04 -1.18669500e-03
#  -2.97086937e-03  1.34536822e-03  2.98469062e-03  7.91346767e-04
#  -5.21806122e-03  3.19291740e-03 -2.77518031e-02 -1.88655995e-02
#   1.38334711e-03 -3.85001491e-03 -5.38257768e-03  8.20115467e-03
# ...

# %% [markdown]
# #### Q3) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code and Execute
predictions = LinearReg.predict(x_test_scaled)

#print(predictions)

# %% [markdown]
# #### Q4) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code and Execute
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
LinearRegression_MAE = mean_absolute_error(y_test, predictions)

# Calculate MSE
LinearRegression_MSE = mean_squared_error(y_test, predictions)

# Calculate R²
LinearRegression_R2 = r2_score(y_test, predictions)

# Print the results
print(f"Mean Absolute Error (MAE): {LinearRegression_MAE}")
print(f"Mean Squared Error (MSE): {LinearRegression_MSE}")
print(f"R-squared (R²): {LinearRegression_R2}")

# Another way to show the data in a different format
Report = pd.DataFrame(data=[['Linear Regression', LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2]],
                      columns=['Model', 'MAE', 'MSE', 'R2'])
Report
# Out:
# Mean Absolute Error (MAE): 0.2563176099420381
# Mean Squared Error (MSE): 0.11572058282746572
# R-squared (R²): 0.42713210736230156
#                Model       MAE       MSE        R2
# 0  Linear Regression  0.256318  0.115721  0.427132

# %% [markdown]
# #### Q5) Show the MAE, MSE, and R2 in a tabular format using data frame for the linear model.

# %%
#Enter Your Code and Execute
# Create a DataFrame to display the metrics
metrics_df = pd.DataFrame({
    'Metric': ['Mean Absolute Error', 'Mean Squared Error', 'R-squared'],
    'Value': [LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2]
})

# Set 'Metric' as the index for better readability
metrics_df.set_index('Metric', inplace=True)

# Display the DataFrame
print(metrics_df)
# Out:
#                         Value
# Metric
# Mean Absolute Error  0.256318
# Mean Squared Error   0.115721
# R-squared            0.427132

# %% [markdown]
# ### KNN

# %% [markdown]
# #### Q6) Create and train a KNN model called KNN using the training data (`x_train`, `y_train`) with the `n_neighbors` parameter set to `4`.

# %%
KNN = KNeighborsClassifier(n_neighbors=4).fit(x_train_scaled, y_train)
predictionsKNN = KNN.predict(x_test_scaled)
KNN_Accuracy_Score = accuracy_score(y_test, predictionsKNN)
KNN_JaccardIndex = jaccard_score(y_test, predictionsKNN)
KNN_F1_Score = f1_score(y_test, predictionsKNN)
Report = pd.DataFrame(data=[['KNN', KNN_Accuracy_Score, KNN_JaccardIndex, KNN_F1_Score]],
                      columns=['Model', 'Accuracy Score', 'Jaccard Index', 'F1 Score'])
Report
# Out:
#   Model  Accuracy Score  Jaccard Index  F1 Score
# 0   KNN        0.760305       0.237864  0.384314

# %%
''' This question is asking to use K-Nearest Neighbors which is a classification algorith. However, we have been dealing with linear regression which is continuous in nature. Thus, we need tp prepare our existing data for classification algorithms. WARNING - The preceding statement may not be true because I was able to create a KNN Classifier and fit the data (see cell above). However, I'm leaving the code below because it's kind of cool stuff.
Determining the number of bins to use for discretizing the target variable in a classification task, particularly when transitioning from regression to classification (as you are with KNN), is a crucial decision that can influence model performance. While the number of bins doesn't directly depend on the feature count, there are several factors to consider when choosing the number of bins (e.g. nature of the target variable, continuous distribution, skewed distribution, dataset size, etc.)
'''
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import KBinsDiscretizer
import numpy as np

# Determine optimum number of bins ty trying different numbers of bins
bin_sizes = [3, 5, 10, 20]
best_score = -np.inf
best_bins = None

# Loop through different bin sizes
for n_bins in bin_sizes:
    # Discretize target variable with different n_bins
    binner = KBinsDiscretizer(n_bins=n_bins, encode='ordinal', strategy='uniform')
    y_train_discrete = binner.fit_transform(y_train_array).ravel()

    # Train the model
    knn = KNeighborsClassifier(n_neighbors=4)
    score = cross_val_score(knn, x_train_scaled, y_train_discrete, cv=5, scoring='accuracy').mean()

    # Track best score and number of bins
    if score > best_score:
        best_score = score
        best_bins = n_bins

print(f"Best number of bins: {best_bins} with score: {best_score}")
# Out:
# Best number of bins: 3 with score: 0.7308912177251032

# %%
#Enter Your Code and Execute
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import KBinsDiscretizer

# This question is asking to use K-Nearest Neighbors which is a classification algorith. I kept receiving the following error:
# 'ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target 
#with continuous values.' and the only way I could find a way to proceed was to create discrete values for y. UPDATE: I tried again and I didn't have to discretize the data

# Step 1: Convert y_train (Pandas Series) to a NumPy array
y_train_array = y_train.to_numpy().reshape(-1, 1)

# Step 2: Perform discretization to turn the continuous regression targets into categorical values suitable for classification.
binner = KBinsDiscretizer(n_bins=best_bins, encode='ordinal', strategy='uniform')  # We determined the optimal number of bins above
y_train_discrete = binner.fit_transform(y_train_array).ravel()

# Step 3: Use the discretized target variable with KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 4)

# %% [markdown]
# #### Q7) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code and Execute
# Fit the model using the training data
knn.fit(x_train_scaled, y_train_discrete)
predictions = knn.predict(x_test_scaled)

# %% [markdown]
# #### Q8) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code and Execute
from sklearn.metrics import accuracy_score, jaccard_score, f1_score

# Discretize y_test using the same binner
y_test_array = y_test.to_numpy().reshape(-1, 1)
y_test_discrete = binner.transform(y_test_array).ravel()  # Apply transformation

# Now, you can calculate the metrics
from sklearn.metrics import accuracy_score, jaccard_score, f1_score, log_loss

# Calculate Accuracy
knn_accuracy = accuracy_score(y_test_discrete, predictions)
print(f"Accuracy: {knn_accuracy}")

# Calculate Jaccard Index (Note: for binary classification, use average='binary', or 'micro'/'macro' for multi-class)
knn_jaccard = jaccard_score(y_test_discrete, predictions, average='macro')  # Use 'micro' or 'macro' for multi-class
print(f"Jaccard Index: {knn_jaccard}")

# Calculate F1 Score (for multi-class, use average='micro' or 'macro')
knn_f1 = f1_score(y_test_discrete, predictions, average='macro')  # Use 'micro' or 'macro' for multi-class
print(f"F1 Score: {knn_f1}")

# Calculate the log loss
knn_probabilities = knn.predict_proba(x_test_scaled)
knn_log_loss = log_loss(y_test_discrete, knn_probabilities)

print(f"KNN Log Loss: {knn_log_loss}")
# Out:
# Accuracy: 0.7603053435114504
# Jaccard Index: 0.48939408503957194
# F1 Score: 0.6177492798067095
# KNN Log Loss: 2.554422591560774

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### Q9) Create and train a Decision Tree model called Tree using the training data (`x_train`, `y_train`).

# %%
#Enter Your Code and Execute
from sklearn.tree import DecisionTreeClassifier

# Create and train the Decision Tree model
tree = DecisionTreeClassifier(random_state=10)
tree.fit(x_train_scaled, y_train_discrete)  # Use y_train_discrete if you're classifying
# Out:
# DecisionTreeClassifier(random_state=10)

# %% [markdown]
# #### Q10) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code and Execute
# Make predictions on the test data
predictions = tree.predict(x_test_scaled)

# %% [markdown]
# #### Q11) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code and Execute
from sklearn.metrics import accuracy_score, jaccard_score, f1_score, log_loss

# Accuracy
tree_accuracy = accuracy_score(y_test_discrete, predictions)
print(f"Accuracy: {tree_accuracy}")

# Jaccard Index
tree_jaccard = jaccard_score(y_test_discrete, predictions, average='macro')  # For multi-class, use 'macro' or 'micro'
print(f"Jaccard Index: {tree_jaccard}")

# F1 Score
tree_f1 = f1_score(y_test_discrete, predictions, average='macro')  # For multi-class, use 'macro' or 'micro'
print(f"F1 Score: {tree_f1}")

# Get predicted probabilities for the Decision Tree model
tree_probabilities = tree.predict_proba(x_test_scaled)

# Calculate log loss
tree_log_loss = log_loss(y_test_discrete, tree_probabilities)

print(f"Decision Tree Log Loss: {tree_log_loss}")
# Out:
# Accuracy: 0.7526717557251908
# Jaccard Index: 0.5502202104232934
# F1 Score: 0.6968839983545866
# Decision Tree Log Loss: 8.91461350998012

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Q12) Use the `train_test_split` function to split the `features` and `Y` dataframes with a `test_size` of `0.2` and the `random_state` set to `1`.

# %%
#Enter Your Code and Execute
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 1: Split the data
x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size=0.2, random_state=1)

# Step 2: Initialize the scaler
scaler = StandardScaler()

# Step 3: Fit the scaler on the training data
x_train_scaled = scaler.fit_transform(x_train)

# Step 4: Transform the test data using the same scaler
x_test_scaled = scaler.transform(x_test)

# Step 5: Initialize the logistic regression model
log_reg = LogisticRegression()

y_train_array = y_train.to_numpy().reshape(-1, 1)

# Step 6: Perform discretization to turn the continuous regression targets into categorical values suitable for classification.
binner = KBinsDiscretizer(n_bins=best_bins, encode='ordinal', strategy='uniform')  # We determined the optimal number of bins above
y_train_discrete = binner.fit_transform(y_train_array).ravel()

# Step 7: Train the model using the scaled training data
log_reg.fit(x_train_scaled, y_train_discrete)

# Step 8: Make predictions on the test data
predictions = log_reg.predict(x_test_scaled)

# Step 9: Evaluate the model
accuracy = accuracy_score(y_test_discrete, predictions)
conf_matrix = confusion_matrix(y_test_discrete, predictions)
class_report = classification_report(y_test_discrete, predictions)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.6045801526717557
# Confusion Matrix:
# [[361 110]
#  [149  35]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.77      0.74       471
#          2.0       0.24      0.19      0.21       184
#
#     accuracy                           0.60       655
#    macro avg       0.47      0.48      0.47       655
# weighted avg       0.58      0.60      0.59       655

# %% [markdown]
# #### Q13) Create and train a LogisticRegression model called LR using the training data (`x_train`, `y_train`) with the `solver` parameter set to `liblinear`.

# %%
#Enter Your Code and Execute
from sklearn.linear_model import LogisticRegression

# Step 1: Initialize the logistic regression model with the solver 'liblinear'
LR = LogisticRegression(solver='liblinear')

# Step 2: Train the model using the scaled training data
LR.fit(x_train_scaled, y_train_discrete)
# Out:
# LogisticRegression(solver='liblinear')

# %% [markdown]
# #### Q14) Now, use the `predict` and `predict_proba` methods on the testing data (`x_test`) and save it as 2 arrays `predictions` and `predict_proba`.

# %%
#Enter Your Code and Execute
# Step 1: Use the trained model to predict the labels for the test data
predictions = LR.predict(x_test_scaled)

# Step 2: Use the trained model to predict the probabilities for the test data
predict_proba = LR.predict_proba(x_test_scaled)

# %% [markdown]
# #### Q15) Using the `predictions`, `predict_proba` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code and Execute
from sklearn.metrics import accuracy_score, jaccard_score, f1_score, log_loss

# Accuracy
log_reg_accuracy = accuracy_score(y_test_discrete, predictions)

# Jaccard Index (for binary classification or using an average method for multiclass)
log_reg_jaccard = jaccard_score(y_test_discrete, predictions, average='macro')  # Use 'binary' for binary classification

# F1 Score (use 'macro' for multiclass or 'binary' for binary classification)
log_reg_f1 = f1_score(y_test_discrete, predictions, average='macro')

# Log Loss (using predict_proba)
log_reg_log_loss = log_loss(y_test_discrete, predict_proba)

# Print the metrics
print(f"Accuracy: {log_reg_accuracy}")
print(f"Jaccard Index: {log_reg_jaccard}")
print(f"F1 Score: {log_reg_f1}")
print(f"Log Loss: {log_reg_log_loss}")
# Out:
# Accuracy: 0.601526717557252
# Jaccard Index: 0.34863775065387964
# F1 Score: 0.47244089628420394
# Log Loss: 0.9950718983226732

# %% [markdown]
# ### SVM

# %% [markdown]
# #### Q16) Create and train a SVM model called SVM using the training data (`x_train`, `y_train`).

# %%
#Enter Your Code and Execute
from sklearn.svm import SVC

# Step 1: Initialize the SVM model
SVM = SVC(probability=True)

# Step 2: Train the SVM model using the scaled training data
SVM.fit(x_train_scaled, y_train_discrete)
# Out:
# SVC(probability=True)

# %% [markdown]
# #### Q17) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code and Execute
# Use the trained SVM model to predict the labels for the test data
predictions = SVM.predict(x_test_scaled)
#print(predictions)

# %% [markdown]
# #### Q18) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
from sklearn.metrics import accuracy_score, jaccard_score, f1_score, log_loss

# Accuracy
svm_accuracy = accuracy_score(y_test_discrete, predictions)

# Jaccard Index (for binary classification or using an average method for multiclass)
svm_jaccard = jaccard_score(y_test_discrete, predictions, average='macro')  # Use 'binary' for binary classification

# F1 Score (use 'macro' for multiclass or 'binary' for binary classification)
svm_f1 = f1_score(y_test_discrete, predictions, average='macro')

# Log Loss (using predict_proba)
predict_proba = SVM.predict_proba(x_test_scaled)
svm_log_loss = log_loss(y_test_discrete, predict_proba)

# Print the metrics
print(f"Accuracy: {svm_accuracy}")
print(f"Jaccard Index: {svm_jaccard}")
print(f"F1 Score: {svm_f1}")
print(f"Log Loss: {svm_log_loss}")
# Out:
# Accuracy: 0.6213740458015267
# Jaccard Index: 0.3555568345323741
# F1 Score: 0.4736501023926174
# Log Loss: 0.9064358833130569

# %% [markdown]
# ### Report

# %% [markdown]
# #### Q19) Show the Accuracy,Jaccard Index,F1-Score and LogLoss in a tabular format using data frame for all of the above models.
#
# \*LogLoss is only for Logistic Regression Model

# %%
import pandas as pd

# Consolidate the calculated metrics for each model
metrics_data = {
    'Model': ['Logistic Regression', 'KNN', 'Decision Tree', 'SVM'],
    'Accuracy': [log_reg_accuracy, knn_accuracy, tree_accuracy, svm_accuracy],
    'Jaccard Index': [log_reg_jaccard, knn_jaccard, tree_jaccard, svm_jaccard],
    'F1 Score': [log_reg_f1, knn_f1, tree_f1, svm_f1],
    'Log Loss': [log_reg_log_loss, knn_log_loss, tree_log_loss, svm_log_loss]
}

# Convert the dictionary to a DataFrame
metrics_df = pd.DataFrame(metrics_data)

# Display the DataFrame
print(metrics_df)
# Out:
#                  Model  Accuracy  Jaccard Index  F1 Score  Log Loss
# 0  Logistic Regression  0.601527       0.348638  0.472441  0.995072
# 1                  KNN  0.760305       0.489394  0.617749  2.554423
# 2        Decision Tree  0.752672       0.550220  0.696884  8.914614
# 3                  SVM  0.621374       0.355557  0.473650  0.906436

# %% [markdown]
# <h2 id="Section_5">  How to submit </h2>
#
# <p>Once you complete your notebook you will have to share it. You can download the notebook by navigating to "File" and clicking on "Download" button.
#
# <p>This will save the (.ipynb) file on your computer. Once saved, you can upload this file in the "My Submission" tab, of the "Peer-graded Assignment" section.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# ### Other Contributors
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0232ENSkillsNetwork30654641-2022-01-01)

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <!--
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description          |
# | ----------------- | ------- | ------------- | --------------------------- |
# | 2022-06-22        | 2.0     | Svitlana K.   | Deleted GridSearch and Mock |
# --!>
